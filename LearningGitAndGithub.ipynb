# %% [markdown]
# # Learning Git & Github and linking it to Jupyter

# %% [markdown]
# Before moving on to learn more about Python and it's various data science capabilities, I decided that it was important that I figure out Git & Github. I'm really hoping to link my Jupyter notebooks of Python to Github, rather than simply the HTML files of my notebooks as seen here:

# %%
# Importing os to change between directories since my screen shot was in a different folder
import os
os.chdir('blog')

# %%
cd ..
# Out:
# /Users/rorypulvino/Dropbox (Personal)/Python/blog

# %%
from IPython.display import Image
Image(filename='github_page.png',width=700,height=600)

# %% [markdown]
# I'd like my notebooks to be uploaded into a separate folder such that others could download and edit them as needed. To do this I've been attempting to follow these directions:

# %%
from IPython.display import Image
Image(filename='deploy_github.png',width=700)

# %% [markdown]
# Unfortunately, this doesn't quite work to update the github page with the actual notebooks it appears. I decided to create a new repository in github ('blog_data') for this and to try and connect it to my folder housing all my jupyter notebooks. To do so I went into the folder in the terminal, use 'git init' to initialize a repository (not sure if this was needed) and then added the folder as a remote origin via 'git remote set-url origin https://github.com/rvino/blog_data.git'. From this point I use 'git add' and 'git commit' to incorporate my jupyter notebook to the repository and then used 'git push origin master' to push it to the actual github page. This results in an authentication error when I tried to enter my username and password.
#
# I finally found the authentication error to be that I had switched my security settings on github to be a two stage authentication. I wasn't quite able to figure out how to use the token (https://help.github.com/articles/creating-an-access-token-for-command-line-use/) to then get past this issue (see http://stackoverflow.com/questions/17659206/git-push-results-in-authentication-failed), but will investigate this issue more. For right now I found a temporary solution to link the folders and now my jupyter notebooks are uploaded in a separate repository.
